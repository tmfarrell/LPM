# %%
import pandas as pd

d = pd.read_table('mA_stats_Rh_20151111.txt')

# %%
d.describe()
# Out:
#        ReferenceID        Length Aligned  AlignedLength  Identity  \
# count            0    516.000000     516            516       516
# mean           NaN    658.821705       0              0         0
# std            NaN   1290.776665       0              0         0
# min            NaN     11.000000   False              0         0
# 25%            NaN    272.750000       0              0         0
# 50%            NaN    361.500000       0              0         0
# 75%            NaN    547.000000       0              0         0
# max            NaN  18038.000000   False              0         0
#
#        ReadCoverage  ReferenceCoverage  MismatchPerBase  InsertionPerBase  \
# count           516                516              516               516
# mean              0                  0                0                 0
# std               0                  0                0                 0
# min               0                  0                0                 0
# ...
