# %%
import pickle

# %%
import pandas as pd

# %%
S = pickle.load(open('../../results/Rh_classifier/All_Stats.p','rb'))

# %%
S
# Out:
#      F-measure   FP-rate  accuracy antigen                  classifier  gene  \
# 0     0.905983  0.121212  0.881720       C                         SVC  RHCE
# 1     0.640000  0.032787  0.806452       E                         SVC  RHCE
# 2     0.943182  1.000000  0.892473       D                         SVC  RHCE
# 3     1.000000  0.000000  1.000000       c                         SVC  RHCE
# 4          NaN       NaN  0.526882   DCcEe                         SVC  RHCE
# 5     0.966667  1.000000  0.935484       e                         SVC  RHCE
# 6          NaN       NaN  0.978495       c      DecisionTreeClassifier  RHCE
# 7          NaN       NaN  0.806452       e      DecisionTreeClassifier  RHCE
# 8          NaN       NaN  0.731183       D      DecisionTreeClassifier  RHCE
# 9          NaN       NaN  0.709677       C      DecisionTreeClassifier  RHCE
# 10         NaN       NaN  0.236559   DCcEe      DecisionTreeClassifier  RHCE
# ...

# %%
S[S['antigen'] == 'DCcEe'].sort(columns=['accuracy'], ascending=False)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/envs/rh_classifier/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#      F-measure  FP-rate  accuracy antigen                  classifier  gene  \
# 244        NaN      NaN  0.903226   DCcEe                         SVC  RHCE
# 592        NaN      NaN  0.860215   DCcEe                         SVC   RHD
# 286        NaN      NaN  0.849462   DCcEe          LogisticRegression  RHCE
# 634        NaN      NaN  0.849462   DCcEe          LogisticRegression   RHD
# 616        NaN      NaN  0.795699   DCcEe      DecisionTreeClassifier   RHD
# 268        NaN      NaN  0.784946   DCcEe      DecisionTreeClassifier  RHCE
# 118        NaN      NaN  0.763441   DCcEe          LogisticRegression  RHCE
# 628        NaN      NaN  0.763441   DCcEe      RandomForestClassifier   RHD
# ...
